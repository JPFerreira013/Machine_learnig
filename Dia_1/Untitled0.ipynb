# %%
#Conjuntos - SETS - No pueden tener elementos repetidos
conjuntos = {"hola", "que", "tal, 2}
conjuntos
# Out:
#   File "<ipython-input-2-efb0ad133904>", line 2
#     conjuntos = {"hola", "que", "tal, 2}
#                                 ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
lista = [2,3,4,1,2,"hola"]
list(set(lista))
# Out:
# [1, 2, 3, 4, 'hola']

# %%
#Diccionarios
diccionario = {0:"hola", 1:"que",2:"tal", "Joao":12345677}
diccionario [2]
# Out:
# 'tal'

# %%
lista_numeros
