# %%
import pandas as pd
import numpy as np

# %%
# Ler o CSV
df = pd.read_csv("ruta_archivo.cvc")

# %%
#Exportar resultado para CSV
df.to_cvc("resultado.csv")

# %%
lista ["banana", "abacate", "uva"]

# %% [markdown]
# # Ejercicio 1
#
# Obtener las primeras `3` filas de un objeto `DataFrame`.

# %%
#Datos
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución, aquí tu respuesta
#Selecionar filas del DF
#df.head()
df[0:5]
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No

# %% [markdown]
# # Ejercicio 2
#
# Obtener las últimas `3` filas de un objeto `DataFrame`.

# %%
#Datos
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución
df[-3:]
# Out:
#    nombre  puntaje  intentos califico
# h   Edgar      NaN         1       No
# i   Angie      8.0         2       No
# j  Irlesa     18.0         1       Sí

# %% [markdown]
# # Ejercicio 3
#
# Seleccionar las columnas ['nombre', 'califico'] de un objeto `DataFrame`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución
lista_columnas = ["nombre", "califico"]
df[lista_columnas]
# Out:
#     nombre califico
# a    Oliva       Sí
# b  Daniela       No
# c     Juan       Sí
# d   Germán       No
# e   Edward       No
# f     Alex       Sí
# g    Julio       Sí
# h    Edgar       No
# i    Angie       No
# j   Irlesa       Sí

# %%
df[["nombre", "califico"]]
# Out:
#     nombre califico
# a    Oliva       Sí
# b  Daniela       No
# c     Juan       Sí
# d   Germán       No
# e   Edward       No
# f     Alex       Sí
# g    Julio       Sí
# h    Edgar       No
# i    Angie       No
# j   Irlesa       Sí

# %% [markdown]
# # Ejercicio 4
#
# Comprobar si este objeto `DataFrame` está vacío con `empty`.

# %%
df = pd.DataFrame({'X': []})

df
# Out:
# Empty DataFrame
# Columns: [X]
# Index: []

# %%
#Solución
# Comprobar si el DataFrame está vacío
esta_vacio = df.empty

# Imprimir el resultado
print("¿El DataFrame está vacío?", esta_vacio)
# Out:
# ¿El DataFrame está vacío? True

# %% [markdown]
# # Ejercicio 5
#
# Crear un objeto `DataFrame` a partir de objetos `Series`.

# %%
#Partimos de dos series
nombres = pd.Series(['Edward', 'Germán', 'Daniela'])
edades = pd.Series([27, 23, 19])

# %%
#Solución
#1. Metemos las series en un diccionario
personas = {'nombre': nombres, 'edades': edades }

#2. Metemos el diccionario dentro de un dataframe
df = pd.DataFrame(data=personas)
df
# Out:
#     nombre  edades
# 0   Edward      27
# 1   Germán      23
# 2  Daniela      19

# %% [markdown]
# # Ejercicio 6
#
# Determinar los datos en un `DataFrame` que son nulos (NaN).

# %%
nombres = ['Edward', 'Daniela', 'Germán']
edades = [5, 6, np.nan]
fecha_nacimiento = [pd.Timestamp('1990-01-03'), None, np.nan]

personas = {'nombre': nombres, 'edad': edades, 'fecha_nacimiento': fecha_nacimiento}

df = pd.DataFrame(data=personas)

df
# Out:
#     nombre  edad fecha_nacimiento
# 0   Edward   5.0       1990-01-03
# 1  Daniela   6.0              NaT
# 2   Germán   NaN              NaT

# %%
#Solución
df.isnull()
# Out:
#    nombre   edad  fecha_nacimiento
# 0   False  False             False
# 1   False  False              True
# 2   False   True              True

# %%
df.isna().sum()
# Out:
# nombre              0
# edad                1
# fecha_nacimiento    2
# dtype: int64

# %% [markdown]
# # Ejercicio 7
#
# Modificar un valor o entrada específico de un objeto `DataFrame` usando `loc`.

# %%
datos = {'X': [1, 2, 3, 4, 5], 'Y': [5, 4, 3, 2, 1], 'Z': [2, 3, 5, 7, 11]}

indices = ['a', 'b', 'c', 'd', 'e']

df = pd.DataFrame(data=datos, index=indices)

df
# Out:
#    X  Y   Z
# a  1  5   2
# b  2  4   3
# c  3  3   5
# d  4  2   7
# e  5  1  11

# %%
#Solución de 1 valor
df.loc["a","X"]
# Out:
# 1

# %%
# Selecionar 2 filas y 2 culumnas
df.loc[["a","b"],["X", "Y"]]
# Out:
#    X  Y
# a  1  5
# b  2  4

# %%
#Selecionar todas as filas e 3 colunas
df.loc[:,["X","Y"]]
# Out:
#    X  Y
# a  1  5
# b  2  4
# c  3  3
# d  4  2
# e  5  1

# %%
#Para modificar o valor , seleciona y modifica
df.loc["a","X"] = 8
df
# Out:
#    X  Y   Z
# a  8  5   2
# b  2  4   3
# c  3  3   5
# d  4  2   7
# e  5  1  11

# %% [markdown]
# # Ejercicio 8
#
# Acceder a un valor o entrada específico de un objeto `DataFrame` usando `loc`.

# %%
datos = {'X': [1, 2, 3, 4, 5], 'Y': [5, 4, 3, 2, 1], 'Z': [2, 3, 5, 7, 11]}

indices = ['a', 'b', 'c', 'd', 'e']

df = pd.DataFrame(data=datos, index=indices)

df
# Out:
#    X  Y   Z
# a  1  5   2
# b  2  4   3
# c  3  3   5
# d  4  2   7
# e  5  1  11

# %%
#Solución location normal
df.loc["a","X"]
# Out:
# 1

# %%
#IndexLocation
df.iloc[0,0]
# Out:
# 1

# %% [markdown]
# # Ejercicio 9
#
# Sumar los valores de la columna intentos con `sum`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución
df["intentos"].sum()
# Out:
# 19

# %%
sum(df["intentos"])
# Out:
# 19

# %%
df.loc[:,"intentos"]
# Out:
# a    1
# b    3
# c    2
# d    3
# e    2
# f    3
# g    1
# h    1
# i    2
# j    1
# Name: intentos, dtype: int64

# %% [markdown]
# # Ejercicio 10 (Opcional)
#
#  Agregar una nueva fila a un objeto `DataFrame` por medio de `loc`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución
df.loc["k"] = ["Joao", 20.0, 1,"Si"]
df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí
# k     Joao     20.0         1       Si

# %% [markdown]
# # Ejercicio 11
#
# Eliminar una fila de un `DataFrame` con la función `drop`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df

# %%
#Solución

# %% [markdown]
# # Ejercicio 12
#
# Mostrar los n primeros y últimos registros de un objeto `DataFrame` con `head` y `tail`.

# %%
datos_1 = list(range(1, 101))
datos_2 = list(range(1, 101))

df = pd.DataFrame({'A': datos_1, 'B': datos_2})

df
# Out:
#       A    B
# 0     1    1
# 1     2    2
# 2     3    3
# 3     4    4
# 4     5    5
# ..  ...  ...
# 95   96   96
# 96   97   97
# 97   98   98
# 98   99   99
# 99  100  100
#
# [100 rows x 2 columns]

# %%
#Solución
df.head()
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No

# %%
df.tail()
# Out:
#    nombre  puntaje  intentos califico
# g   Julio     13.5         1       Sí
# h   Edgar      NaN         1       No
# i   Angie      8.0         2       No
# j  Irlesa     18.0         1       Sí
# k    Joao     20.0         1       Si

# %% [markdown]
# # Ejercicio 13
#
# Agregar una nueva columna a un `DataFrame` con notación de slicing.
#
# `df['nombre_nueva_columna'] = valores`

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Valores nueva columna
colores = ['Negro', 'Blanco', 'Azul', 'Verde', 'Rojo', 'Amarillo',
           'Gris', 'Naranja', 'Lila',""]
#Solución
df['colores'] = colores
df
# Out:
#     nombre  puntaje  intentos califico   colores
# a    Oliva     11.5         1       Sí     Negro
# b  Daniela      8.0         3       No    Blanco
# c     Juan     15.5         2       Sí      Azul
# d   Germán      NaN         3       No     Verde
# e   Edward      8.0         2       No      Rojo
# f     Alex     19.0         3       Sí  Amarillo
# g    Julio     13.5         1       Sí      Gris
# h    Edgar      NaN         1       No   Naranja
# i    Angie      8.0         2       No      Lila
# j   Irlesa     18.0         1       Sí

# %% [markdown]
# # Recorrer un df
#
#  Para iterar cada una de las filas de un `DataFrame` utilizamos la función `iterrows`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#TAREA HECHA
for indice, fila in df.iterrows():
    print(fila['nombre'], fila['califico'])
# Out:
# Oliva Sí
# Daniela No
# Juan Sí
# Germán No
# Edward No
# Alex Sí
# Julio Sí
# Edgar No
# Angie No
# Irlesa Sí

# %% [markdown]
# # Ejercicio 14 (Opcional)
#
# Obtener como una lista Python los nombres de las columnas de un `DataFrame`.

# %%
datos = {'X': [1, 2, 3, 4, 5], 'Y': [5, 4, 3, 2, 1], 'Z': [2, 3, 5, 7, 11]}

df = pd.DataFrame(datos)

df

# %%
#Solución

# %% [markdown]
# # Ejercicio 15
#
# Renombrar las columnas de un objeto `DataFrame` a partir del diccionario dado.

# %%
datos = {'Columna1': [1, 2, 3, 4, 5], 'Columna2': [5, 4, 3, 2, 1],
         'Columna3': [2, 3, 5, 7, 11]}

indices = ['a', 'b', 'c', 'd', 'e']

df = pd.DataFrame(data=datos, index=indices)

df

# %%
#Diccionario con los nuevos nombres de las columnas
renombrado_columnas = {'Columna1': 'X', 'Columna2': 'Y', 'Columna3': 'Z'}

# %% [markdown]
# # Ejercicio 16
#
# * Guardar los registros de un `DataFrame` en un archivo de formato **CSV**.
# * Prueba a descargarlos en tu PC.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio',
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos,
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí
